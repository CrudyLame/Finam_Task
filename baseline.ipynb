# %% [markdown]
# # Conversation Processing Pipeline
#
# This notebook implements a three-stage conversation analysis pipeline:
#
# 1. **Stage 1**: Load and parse conversations from CSV → save to JSON
# 2. **Stage 2**: Run problem detection → update conversations with problems
# 3. **Stage 3**: Run UX analysis with Groq → update conversations with UX data
#
# Each stage can be run independently with progress tracking and resume capability.

# %%
import sys
import os
import json
import pandas as pd
from datetime import datetime
from typing import List
from tqdm import tqdm

# Add utils to path
sys.path.append('utils')

# Import custom modules
from utils.conv.parser import ConversationParser
from utils.conv.conversation import Conversation, ConversationMap, RequestCategory, ProblemDetection, UX
from utils.problem_eda import create_problem_detection_for_conversation
from utils.qroq.groq_processor import GroqProcessor

from config import settings

# Configuration
CSV_FILE = 'data/data.csv'
CONVERSATIONS_FILE = 'conversations_parsed.json'
GROQ_API_KEY = settings.api_key

# %% [markdown]
# ## Stage 1: Load and Parse Conversations

# %%
def save_conversations_to_json(conversations: List[Conversation], filename: str):
    """Save conversations to JSON file with metadata."""
    data = {
        'metadata': {
            'total_conversations': len(conversations),
            'created_at': datetime.now().isoformat(),
            'source_file': CSV_FILE,
            'format_version': '2.0'
        },
        'conversations': [conv.model_dump() for conv in conversations]
    }
    
    with open(filename, 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=2, default=str)
    
    print(f"Saved {len(conversations)} conversations to {filename}")

def load_conversations_from_json(filename: str) -> List[Conversation]:
    """Load conversations from JSON file."""
    with open(filename, 'r', encoding='utf-8') as f:
        data = json.load(f)
    
    conversations = []
    for conv_data in data['conversations']:
        # Handle datetime fields
        conv_data['start_time'] = datetime.fromisoformat(conv_data['start_time'])
        conv_data['end_time'] = datetime.fromisoformat(conv_data['end_time'])
        
        # Reconstruct blocks and other complex fields if needed
        conversations.append(Conversation(**conv_data))
    
    print(f"Loaded {len(conversations)} conversations from {filename}")
    return conversations

# Stage 1: Parse conversations from CSV and save
if not os.path.exists(CONVERSATIONS_FILE):
    print("=== Stage 1: Parsing Conversations from CSV ===")
    
    # Initialize parser
    parser = ConversationParser(
        csv_file_path=CSV_FILE,
        time_threshold_minutes=30
    )
    
    print("Parsing conversations from CSV...")
    conversations = parser.parse_conversations()
    
    print(f"Parsed {len(conversations)} conversations")
    print(f"Total users: {len(set(c.user_id for c in conversations))}")
    
    # Get basic statistics
    stats = parser.get_conversation_stats(conversations)
    print("\n=== Conversation Statistics ===")
    for key, value in stats.items():
        print(f"{key}: {value}")
    
    # Save to JSON
    save_conversations_to_json(conversations, CONVERSATIONS_FILE)
    
else:
    print(f"Conversations file {CONVERSATIONS_FILE} already exists. Loading existing data...")
    conversations = load_conversations_from_json(CONVERSATIONS_FILE)

print(f"\n✅ Stage 1 Complete: {len(conversations)} conversations ready for analysis")
# Out:
# Conversations file conversations_parsed.json already exists. Loading existing data...
# Loaded 2055 conversations from conversations_parsed.json
#
# ✅ Stage 1 Complete: 2055 conversations ready for analysis

# %% [markdown]
# ## Stage 2: Problem Detection

# %%
def run_problem_detection(conversations: List[Conversation]) -> List[Conversation]:
    """Run problem detection on all conversations."""
    print("=== Stage 2: Problem Detection ===")
    
    updated_conversations = []
    problem_stats = {}
    
    print(f"Analyzing {len(conversations)} conversations for problems...")
    
    for i, conv in enumerate(tqdm(conversations, desc="Detecting problems")):
        # Create problem detection
        problem_detection = create_problem_detection_for_conversation(conv)
        
        # Update conversation with problem analysis
        conv_copy = conv.model_copy()
        
        # Create or update analysis with problems
        if conv_copy.analysis is None:
            conv_copy.analysis = ConversationMap(
                request=RequestCategory(
                    category=[],
                    intent=[]
                ),
                problems=problem_detection,
                ux=UX(
                    sentiment="neutral",
                    sentiment_confidence=0.5,
                    emotions=[],
                    feedback=[],
                    suggestions=[],
                    is_successful=True
                )
            )
        else:
            conv_copy.analysis.problems = problem_detection
        
        updated_conversations.append(conv_copy)
        
        # Track problem statistics
        for problem in problem_detection.problems:
            problem_stats[problem.value] = problem_stats.get(problem.value, 0) + 1
    
    # Print problem statistics
    print(f"\n=== Problem Detection Results ===")
    total_with_problems = sum(1 for conv in updated_conversations if conv.analysis.problems.problems)
    print(f"Conversations with problems: {total_with_problems}/{len(conversations)} ({total_with_problems/len(conversations)*100:.1f}%)")
    
    print("\nProblem type breakdown:")
    for problem_type, count in sorted(problem_stats.items(), key=lambda x: x[1], reverse=True):
        percentage = count / len(conversations) * 100
        print(f"  {problem_type}: {count} ({percentage:.1f}%)")
    
    return updated_conversations

# Run problem detection if not already done
problems_detected = any(
    conv.analysis and conv.analysis.problems and conv.analysis.problems.problems 
    for conv in conversations[:10]  # Check first 10 conversations
)

if not problems_detected:
    conversations = run_problem_detection(conversations)
    
    # Save updated conversations
    save_conversations_to_json(conversations, CONVERSATIONS_FILE)
    print(f"Updated conversations with problems saved to {CONVERSATIONS_FILE}")
else:
    print("Problem detection already completed. Skipping Stage 2.")

print(f"\n✅ Stage 2 Complete: Problem detection finished")
# Out:
# Problem detection already completed. Skipping Stage 2.
#
# ✅ Stage 2 Complete: Problem detection finished

# %% [markdown]
# ## Stage 3: UX Analysis with Groq

# %%
# Stage 3: UX and Intent Analysis with Groq
import asyncio
import time

async def run_groq_ux_and_intent_analysis():
	"""Run enhanced UX and Intent analysis using the updated GroqProcessor."""
	print("=== Stage 3: Enhanced UX and Intent Analysis with Groq ===")
	
	# Initialize processor with enhanced capabilities
	processor = GroqProcessor(
		api_key=GROQ_API_KEY,
		model_name='llama3-8b-8192',  # Fast, good quality model
		max_concurrent_requests=3,
		batch_size=25,
		conversations_file=CONVERSATIONS_FILE
	)
	
	# Check for existing progress
	can_resume, start_index = processor.get_resume_info(len(conversations))
	
	# Check if analysis is already completed by examining recent conversations
	sample_convs = conversations[max(0, start_index-5):start_index+5] if start_index > 0 else conversations[:10]
	analysis_completed = any(
		conv.analysis and conv.analysis.ux and conv.analysis.request and
		hasattr(conv.analysis.ux, 'sentiment') and 
		conv.analysis.ux.sentiment != "neutral" and
		conv.analysis.request.intent  # Check if intent analysis exists
		for conv in sample_convs
	)
	
	if analysis_completed and start_index >= len(conversations):
		print("Enhanced UX and Intent analysis already completed for all conversations.")
		print("The analysis includes:")
		print("  - UX Analysis: sentiment, emotions, feedback, suggestions")
		print("  - Intent Analysis: user intent classification and categorization")
		return conversations
	
	if can_resume and start_index > 0:
		print(f"Found existing progress: {start_index}/{len(conversations)} conversations processed")
		should_resume = input("Resume from where you left off? (y/n): ").strip().lower()
		if should_resume != 'y':
			start_index = 0
			processor.cleanup_progress()
	
	# Get user confirmation for processing
	remaining_count = len(conversations) - start_index
	print(f"\nAbout to process {remaining_count} conversations with enhanced Groq analysis:")
	print("  • UX Analysis: sentiment, emotions, feedback, suggestions")
	print("  • Intent Analysis: user intent classification and request categorization")
	print("  • Problem Detection: technical issues, user confusion, etc.")
	print(f"  • Model: {processor.model_name}")
	print(f"  • Concurrent requests: {processor.max_concurrent_requests}")
	print(f"  • Batch size: {processor.batch_size}")
	
	process_all = input(f"\nProceed with processing? (y/n): ")
	
	if process_all.lower() == 'y':
		print(f"Starting enhanced Groq analysis from index {start_index}...")
		
		# Run the enhanced processing (includes both UX and Intent analysis)
		start_time = time.time()
		updated_conversations = await processor.process_ux_and_intent_analysis(start_index)
		end_time = time.time()
		
		print(f"\n=== Enhanced Analysis Complete ===")
		print(f"Provider: Groq ({processor.model_name})")
		print(f"Total time: {end_time - start_time:.2f} seconds")
		print(f"Average time per conversation: {(end_time - start_time) / remaining_count:.2f} seconds")
		print(f"Conversations analyzed: {remaining_count}")
		
		# Clean up progress file
		processor.cleanup_progress()
		
		return updated_conversations
	
	else:
		print("Enhanced analysis cancelled")
		return conversations

# Run enhanced UX and Intent analysis
conversations = await run_groq_ux_and_intent_analysis()

print(f"\n✅ Stage 3 Complete: Enhanced UX and Intent analysis finished")
# Out:
# === Stage 3: Enhanced UX and Intent Analysis with Groq ===
# No existing progress found, starting fresh
#
# About to process 2055 conversations with enhanced Groq analysis:
#   • UX Analysis: sentiment, emotions, feedback, suggestions
#   • Intent Analysis: user intent classification and request categorization
#   • Problem Detection: technical issues, user confusion, etc.
#   • Model: llama3-8b-8192
#   • Concurrent requests: 3
#   • Batch size: 25
# Starting enhanced Groq analysis from index 0...
# Starting Groq UX and Intent processing from index 0
# Total conversations to process: 2055
# Successfully initialized Groq client with llama3-8b-8192
# \nProcessing batch 1: conversations 1-25
#   Completed 5/25 in batch
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': 'It would be hel...completing these tasks'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
#   Completed 10/25 in batch
#   Completed 15/25 in batch
#   Completed 20/25 in batch
#   Completed 25/25 in batch
#   Batch completed in 7.69s
#   Successful: 25, Failed: 0
#   Total processed: 25/2055
# \nProcessing batch 2: conversations 26-50
#   Completed 5/25 in batch
#   Completed 10/25 in batch
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'type': 'improvement', '...шений and Coursor'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Error parsing UX analysis: 2 validation errors for UX
# feedback.0
#   Input should be a valid string [type=string_type, input_value={'category': 'system_perf...m performance feedback'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'category': 'improvement...f authorship for tasks'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
#   Completed 15/25 in batch
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'type': 'task management...tion within the system'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
#   Completed 20/25 in batch
#   Completed 25/25 in batch
#   Batch completed in 6.93s
#   Successful: 25, Failed: 0
#   Total processed: 50/2055
# \nProcessing batch 3: conversations 51-75
#   Completed 5/25 in batch
# Rate limit hit for conversation 849, waiting 1.55s (attempt 1/3)
# Rate limit hit for conversation 854, waiting 1.70s (attempt 1/3)
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': 'дополни..., 'type': 'improvement'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 673, waiting 1.99s (attempt 1/3)
#   Completed 10/25 in batch
# Rate limit hit for conversation 674, waiting 1.07s (attempt 1/3)
# Rate limit hit for conversation 755, waiting 1.76s (attempt 1/3)
#   Completed 15/25 in batch
# Error parsing UX analysis: 1 validation error for UX
# feedback.0
#   Input should be a valid string [type=string_type, input_value={'feedback_type': 'info_r... on brokerage accounts'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 855, waiting 1.48s (attempt 1/3)
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'type': 'improvement', '...user (FIO_95) on today'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
#   Completed 20/25 in batch
# Rate limit hit for conversation 756, waiting 1.82s (attempt 1/3)
# Rate limit hit for conversation 919, waiting 1.85s (attempt 1/3)
#   Completed 25/25 in batch
#   Batch completed in 36.01s
#   Successful: 25, Failed: 0
#   Total processed: 75/2055
# \nProcessing batch 4: conversations 76-100
# Rate limit hit for conversation 538, waiting 1.88s (attempt 1/3)
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': 'Write to Nikola..., 'type': 'improvement'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
#   Completed 5/25 in batch
# Rate limit hit for conversation 921, waiting 1.78s (attempt 1/3)
# Rate limit hit for conversation 921, waiting 2.44s (attempt 2/3)
#   Completed 10/25 in batch
# Rate limit hit for conversation 757, waiting 1.83s (attempt 1/3)
# Rate limit hit for conversation 925, waiting 1.73s (attempt 1/3)
#   Completed 15/25 in batch
# Rate limit hit for conversation 925, waiting 2.62s (attempt 2/3)
# Error parsing UX analysis: 1 validation error for UX
# feedback.0
#   Input should be a valid string [type=string_type, input_value={'category': 'information...ojects related to Bony'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
#   Completed 20/25 in batch
# Error parsing UX analysis: 2 validation errors for UX
# feedback.0
#   Input should be a valid string [type=string_type, input_value={'category': 'system perf... performed as expected'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'category': 'task manage...iled task descriptions'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
#   Completed 25/25 in batch
#   Batch completed in 38.20s
#   Successful: 25, Failed: 0
#   Total processed: 100/2055
# \nProcessing batch 5: conversations 101-125
# Rate limit hit for conversation 1013, waiting 1.40s (attempt 1/3)
#   Completed 5/25 in batch
#   Completed 10/25 in batch
# Error parsing UX analysis: 2 validation errors for UX
# feedback.0
#   Input should be a valid string [type=string_type, input_value={'type': 'system_performa...to remaining questions'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'type': 'information_pro...d answers if available'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 398, waiting 1.68s (attempt 1/3)
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': 'It would be gre...egory': 'clarification'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 398, waiting 2.75s (attempt 2/3)
#   Completed 15/25 in batch
# Rate limit hit for conversation 1056, waiting 1.21s (attempt 1/3)
#   Completed 20/25 in batch
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'type': 'improvement', '...s about animal biology'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'type': 'feature suggest... 'comparing AI systems'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
#   Completed 25/25 in batch
#   Batch completed in 36.08s
#   Successful: 25, Failed: 0
#   Total processed: 125/2055
# \nProcessing batch 6: conversations 126-150
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': 'processing', 'type': 'improvement'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
#   Completed 5/25 in batch
# Rate limit hit for conversation 1079, waiting 1.67s (attempt 1/3)
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': 'improve queue v...'category': 'usability'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Error parsing UX analysis: 2 validation errors for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': 'создани...ype': 'feature-request'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# suggestions.1
#   Input should be a valid string [type=string_type, input_value={'text': 'организ...': 'event-organization'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
#   Completed 10/25 in batch
# Rate limit hit for conversation 1017, waiting 1.35s (attempt 1/3)
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': 'провали...ype': 'feature_request'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
#   Completed 15/25 in batch
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': 'Сделай р...ype': 'feature_request'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'category': 'improvement... comprehensive answers'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 1023, waiting 1.10s (attempt 1/3)
#   Completed 20/25 in batch
#   Completed 25/25 in batch
#   Batch completed in 39.35s
#   Successful: 25, Failed: 0
#   Total processed: 150/2055
# \nProcessing batch 7: conversations 151-175
#   Completed 5/25 in batch
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': 'ФФ долже...ype': 'feature request'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 1032, waiting 1.73s (attempt 1/3)
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': 'USA API', 'type': 'information_request'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 8, waiting 1.46s (attempt 1/3)
#   Completed 10/25 in batch
#   Completed 15/25 in batch
#   Completed 20/25 in batch
#   Completed 25/25 in batch
#   Batch completed in 37.17s
#   Successful: 25, Failed: 0
#   Total processed: 175/2055
# \nProcessing batch 8: conversations 176-200
# Rate limit hit for conversation 410, waiting 1.91s (attempt 1/3)
# Rate limit hit for conversation 410, waiting 2.33s (attempt 2/3)
#   Completed 5/25 in batch
# Rate limit hit for conversation 1121, waiting 1.43s (attempt 1/3)
# Rate limit hit for conversation 1123, waiting 1.58s (attempt 1/3)
#   Completed 10/25 in batch
# Rate limit hit for conversation 1124, waiting 1.76s (attempt 1/3)
# Rate limit hit for conversation 1126, waiting 1.68s (attempt 1/3)
#   Completed 15/25 in batch
#   Completed 20/25 in batch
# Rate limit hit for conversation 1131, waiting 1.96s (attempt 1/3)
#   Completed 25/25 in batch
#   Batch completed in 38.73s
#   Successful: 25, Failed: 0
#   Total processed: 200/2055
# \nProcessing batch 9: conversations 201-225
# Rate limit hit for conversation 1134, waiting 1.49s (attempt 1/3)
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'type': 'feature', 'desc... assigned for tomorrow'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
#   Completed 5/25 in batch
# Rate limit hit for conversation 1171, waiting 1.60s (attempt 1/3)
# Rate limit hit for conversation 1171, waiting 2.64s (attempt 2/3)
# Rate limit exceeded for conversation 1171 after 3 attempts
#   Completed 10/25 in batch
#   Completed 15/25 in batch
# Rate limit hit for conversation 840, waiting 1.25s (attempt 1/3)
#   Completed 20/25 in batch
# Rate limit hit for conversation 1184, waiting 1.56s (attempt 1/3)
#   Completed 25/25 in batch
#   Batch completed in 37.65s
#   Successful: 25, Failed: 0
#   Total processed: 225/2055
# \nProcessing batch 10: conversations 226-250
# Rate limit hit for conversation 1190, waiting 1.74s (attempt 1/3)
#   Completed 5/25 in batch
# Rate limit hit for conversation 416, waiting 1.92s (attempt 1/3)
# Error parsing UX analysis: 1 validation error for UX
# feedback.0
#   Input should be a valid string [type=string_type, input_value={'topic': 'agent_system_p... no performance issues'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 417, waiting 1.81s (attempt 1/3)
# Rate limit hit for conversation 1191, waiting 1.10s (attempt 1/3)
#   Completed 10/25 in batch
# Rate limit hit for conversation 420, waiting 1.35s (attempt 1/3)
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'description': 'Provide ...nar', 'priority': 'low'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
#   Completed 15/25 in batch
# Rate limit hit for conversation 423, waiting 1.32s (attempt 1/3)
#   Completed 20/25 in batch
# Rate limit hit for conversation 1196, waiting 1.06s (attempt 1/3)
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': 'allow editing o...ype': 'feature_request'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
#   Completed 25/25 in batch
#   Batch completed in 38.29s
#   Successful: 25, Failed: 0
#   Total processed: 250/2055
# \nProcessing batch 11: conversations 251-275
# Rate limit hit for conversation 1202, waiting 1.50s (attempt 1/3)
#   Completed 5/25 in batch
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': 'оптимиз..., 'type': 'improvement'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 1209, waiting 1.39s (attempt 1/3)
#   Completed 10/25 in batch
# Rate limit hit for conversation 1211, waiting 1.77s (attempt 1/3)
# Rate limit hit for conversation 1215, waiting 1.38s (attempt 1/3)
#   Completed 15/25 in batch
# Rate limit hit for conversation 1216, waiting 1.29s (attempt 1/3)
# Rate limit hit for conversation 315, waiting 1.11s (attempt 1/3)
# Rate limit hit for conversation 1218, waiting 1.03s (attempt 1/3)
#   Completed 20/25 in batch
# Rate limit hit for conversation 12, waiting 1.51s (attempt 1/3)
#   Completed 25/25 in batch
#   Batch completed in 37.95s
#   Successful: 25, Failed: 0
#   Total processed: 275/2055
# \nProcessing batch 12: conversations 276-300
# Rate limit hit for conversation 17, waiting 1.55s (attempt 1/3)
# Rate limit hit for conversation 18, waiting 1.44s (attempt 1/3)
# Rate limit hit for conversation 18, waiting 2.53s (attempt 2/3)
#   Completed 5/25 in batch
#   Completed 10/25 in batch
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': 'It would be hel...ype': 'feature_request'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
#   Completed 15/25 in batch
# Rate limit hit for conversation 1391, waiting 1.93s (attempt 1/3)
# Error parsing UX analysis: 1 validation error for UX
# feedback.0
#   Input should be a valid string [type=string_type, input_value={'type': 'system_performa...any questions for them'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 1391, waiting 1.13s (attempt 1/3)
#   Completed 20/25 in batch
# Rate limit hit for conversation 1393, waiting 1.33s (attempt 1/3)
# Error parsing UX analysis: 1 validation error for UX
# feedback.0
#   Input should be a valid string [type=string_type, input_value={'category': 'agent', 'text': 'none'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 1393, waiting 2.10s (attempt 2/3)
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': 'куда ты ..., 'type': 'improvement'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
#   Completed 25/25 in batch
#   Batch completed in 37.81s
#   Successful: 25, Failed: 0
#   Total processed: 300/2055
# \nProcessing batch 13: conversations 301-325
# Rate limit hit for conversation 857, waiting 1.14s (attempt 1/3)
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'description': 'Add task...es', 'priority': 'high'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': 'скажи ка..., 'type': 'improvement'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 542, waiting 1.56s (attempt 1/3)
#   Completed 5/25 in batch
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'type': 'feature_request...or request fulfillment'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 860, waiting 1.89s (attempt 1/3)
#   Completed 10/25 in batch
# Rate limit hit for conversation 863, waiting 1.43s (attempt 1/3)
#   Completed 15/25 in batch
# Rate limit hit for conversation 543, waiting 1.81s (attempt 1/3)
# Error processing conversation 1418: Error code: 400 - {'error': {'message': "Failed to generate JSON. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'json_validate_failed', 'failed_generation': '{\n   "sentiment": "neutral",\n   "sentiment_confidence": 0.8,\n   "emotions": [],\n   "feedback": [],\n   "suggestions": [{"request_form_for_official_report"}],\n   "is_successful": true\n}'}}
#   Completed 20/25 in batch
# Rate limit hit for conversation 941, waiting 1.63s (attempt 1/3)
# Rate limit hit for conversation 582, waiting 1.47s (attempt 1/3)
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'type': 'improvement', '... for upcoming projects'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
#   Completed 25/25 in batch
#   Batch completed in 39.66s
#   Successful: 25, Failed: 0
#   Total processed: 325/2055
# \nProcessing batch 14: conversations 326-350
# Error parsing UX analysis: 1 validation error for UX
# feedback.0
#   Input should be a valid string [type=string_type, input_value={'type': 'system_performa...t available to respond'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 758, waiting 1.90s (attempt 1/3)
#   Completed 5/25 in batch
# Rate limit hit for conversation 1420, waiting 1.65s (attempt 1/3)
# Rate limit hit for conversation 1420, waiting 2.43s (attempt 2/3)
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'type': 'improve_info', ...le data for colleagues'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit exceeded for conversation 1420 after 3 attempts
#   Completed 10/25 in batch
# Rate limit hit for conversation 189, waiting 1.87s (attempt 1/3)
# Rate limit hit for conversation 682, waiting 1.58s (attempt 1/3)
#   Completed 15/25 in batch
# Rate limit hit for conversation 190, waiting 1.04s (attempt 1/3)
# Rate limit hit for conversation 190, waiting 2.07s (attempt 2/3)
#   Completed 20/25 in batch
# Rate limit hit for conversation 683, waiting 1.53s (attempt 1/3)
#   Completed 25/25 in batch
#   Batch completed in 35.35s
#   Successful: 25, Failed: 0
#   Total processed: 350/2055
# \nProcessing batch 15: conversations 351-375
# Rate limit hit for conversation 192, waiting 1.49s (attempt 1/3)
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'type': 'info_request', ... интеграций'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 192, waiting 2.72s (attempt 2/3)
#   Completed 5/25 in batch
# Rate limit hit for conversation 765, waiting 1.57s (attempt 1/3)
#   Completed 10/25 in batch
# Rate limit hit for conversation 1432, waiting 1.35s (attempt 1/3)
#   Completed 15/25 in batch
# Rate limit hit for conversation 386, waiting 1.43s (attempt 1/3)
#   Completed 20/25 in batch
#   Completed 25/25 in batch
#   Batch completed in 40.03s
#   Successful: 25, Failed: 0
#   Total processed: 375/2055
# \nProcessing batch 16: conversations 376-400
# Error parsing UX analysis: 1 validation error for UX
# feedback.0
#   Input should be a valid string [type=string_type, input_value={'topic': 'user understan... 'sentiment': 'neutral'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': 'покажи, ...rove_conversation_flow'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': 'договор...ут налажены'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
#   Completed 5/25 in batch
# Rate limit hit for conversation 1523, waiting 1.37s (attempt 1/3)
# Rate limit hit for conversation 1523, waiting 2.28s (attempt 2/3)
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': 'названи...uat', 'type': 'request'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 595, waiting 1.81s (attempt 1/3)
#   Completed 10/25 in batch
# Rate limit hit for conversation 596, waiting 1.07s (attempt 1/3)
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': 'библиот...айну финама'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 28, waiting 1.57s (attempt 1/3)
#   Completed 15/25 in batch
# Rate limit hit for conversation 28, waiting 1.19s (attempt 1/3)
# Rate limit hit for conversation 32, waiting 1.63s (attempt 1/3)
#   Completed 20/25 in batch
# Rate limit hit for conversation 34, waiting 1.32s (attempt 1/3)
#   Completed 25/25 in batch
#   Batch completed in 39.61s
#   Successful: 25, Failed: 0
#   Total processed: 400/2055
# \nProcessing batch 17: conversations 401-425
# Error parsing UX analysis: 2 validation errors for UX
# feedback.0
#   Input should be a valid string [type=string_type, input_value={'category': 'missing_inf...additional information'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'category': 'improve_sea... more relevant results'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Error parsing UX analysis: 1 validation error for UX
# feedback.0
#   Input should be a valid string [type=string_type, input_value={'type': 'information req...nternal knowledge base'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 1526, waiting 1.03s (attempt 1/3)
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'description': 'Provide ...y': 'Conversation Flow'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
#   Completed 5/25 in batch
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'type': 'improvement', '...rket-related questions'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
#   Completed 10/25 in batch
# Rate limit hit for conversation 1527, waiting 1.70s (attempt 1/3)
# Rate limit hit for conversation 1527, waiting 2.41s (attempt 2/3)
# Rate limit exceeded for conversation 1527 after 3 attempts
#   Completed 15/25 in batch
# Rate limit hit for conversation 1559, waiting 1.88s (attempt 1/3)
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': 'Adding links to...': 'system Improvement'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 1085, waiting 1.07s (attempt 1/3)
#   Completed 20/25 in batch
#   Completed 25/25 in batch
#   Batch completed in 36.77s
#   Successful: 25, Failed: 0
#   Total processed: 425/2055
# \nProcessing batch 18: conversations 426-450
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'description': 'create t... clients automatically'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 1579, waiting 1.28s (attempt 1/3)
#   Completed 5/25 in batch
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': 'знай все..., 'type': 'improvement'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 1584, waiting 1.03s (attempt 1/3)
#   Completed 10/25 in batch
# Rate limit hit for conversation 1163, waiting 1.90s (attempt 1/3)
# Rate limit hit for conversation 435, waiting 1.32s (attempt 1/3)
# Rate limit hit for conversation 435, waiting 2.16s (attempt 2/3)
#   Completed 15/25 in batch
# Rate limit hit for conversation 1618, waiting 1.30s (attempt 1/3)
#   Completed 20/25 in batch
#   Completed 25/25 in batch
#   Batch completed in 38.30s
#   Successful: 25, Failed: 0
#   Total processed: 450/2055
# \nProcessing batch 19: conversations 451-475
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'type': 'feature_request...: 'pre ipo information'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 1622, waiting 1.99s (attempt 1/3)
#   Completed 5/25 in batch
# Rate limit hit for conversation 948, waiting 1.15s (attempt 1/3)
# Rate limit hit for conversation 950, waiting 1.05s (attempt 1/3)
#   Completed 10/25 in batch
# Rate limit hit for conversation 843, waiting 1.61s (attempt 1/3)
# Rate limit hit for conversation 843, waiting 2.20s (attempt 2/3)
# Error parsing UX analysis: 2 validation errors for UX
# feedback.0
#   Input should be a valid string [type=string_type, input_value={'topic': 'agent system p... presentation creation'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'topic': 'system improve...te express information'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 1400, waiting 1.64s (attempt 1/3)
#   Completed 15/25 in batch
# Rate limit hit for conversation 1528, waiting 1.89s (attempt 1/3)
#   Completed 20/25 in batch
# Rate limit hit for conversation 1402, waiting 1.07s (attempt 1/3)
#   Completed 25/25 in batch
#   Batch completed in 37.60s
#   Successful: 25, Failed: 0
#   Total processed: 475/2055
# \nProcessing batch 20: conversations 476-500
# Rate limit hit for conversation 1658, waiting 1.45s (attempt 1/3)
#   Completed 5/25 in batch
# Rate limit hit for conversation 329, waiting 1.30s (attempt 1/3)
# Rate limit hit for conversation 440, waiting 1.97s (attempt 1/3)
#   Completed 10/25 in batch
# Rate limit hit for conversation 442, waiting 1.48s (attempt 1/3)
# Rate limit hit for conversation 137, waiting 1.81s (attempt 1/3)
#   Completed 15/25 in batch
# Rate limit hit for conversation 1219, waiting 1.26s (attempt 1/3)
# Rate limit hit for conversation 1220, waiting 2.00s (attempt 1/3)
# Error parsing UX analysis: 2 validation errors for UX
# feedback.0
#   Input should be a valid string [type=string_type, input_value={'type': 'agent', 'text': 'none'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'type': 'feature', 'text...у через Толк'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
#   Completed 20/25 in batch
# Rate limit hit for conversation 1223, waiting 1.45s (attempt 1/3)
#   Completed 25/25 in batch
#   Batch completed in 37.44s
#   Successful: 25, Failed: 0
#   Total processed: 500/2055
# \nProcessing batch 21: conversations 501-525
# Rate limit hit for conversation 1228, waiting 1.83s (attempt 1/3)
#   Completed 5/25 in batch
# Rate limit hit for conversation 445, waiting 1.32s (attempt 1/3)
#   Completed 10/25 in batch
# Rate limit hit for conversation 448, waiting 1.70s (attempt 1/3)
# Rate limit hit for conversation 449, waiting 1.68s (attempt 1/3)
#   Completed 15/25 in batch
# Error parsing UX analysis: 1 validation error for UX
# feedback.0
#   Input should be a valid string [type=string_type, input_value={'topic': 'information', ...ion about SQL requests'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'description': 'show res...'category': 'interface'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
#   Completed 20/25 in batch
# Rate limit hit for conversation 1671, waiting 1.93s (attempt 1/3)
# Rate limit hit for conversation 1236, waiting 1.05s (attempt 1/3)
#   Completed 25/25 in batch
#   Batch completed in 39.66s
#   Successful: 25, Failed: 0
#   Total processed: 525/2055
# \nProcessing batch 22: conversations 526-550
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': 'покажи о...ype': 'feature_request'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 1239, waiting 1.99s (attempt 1/3)
#   Completed 5/25 in batch
# Rate limit hit for conversation 1243, waiting 1.00s (attempt 1/3)
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'description': 'Provide ..., 'category': 'content'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 1242, waiting 1.49s (attempt 1/3)
# Error parsing UX analysis: 1 validation error for UX
# feedback.0
#   Input should be a valid string [type=string_type, input_value={'type': 'information_req...ов записала'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
#   Completed 10/25 in batch
# Rate limit hit for conversation 1672, waiting 1.52s (attempt 1/3)
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': 'ежеднев...ype': 'feature_request'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': 'сколько ... 'type': 'info_request'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
#   Completed 15/25 in batch
# Rate limit hit for conversation 459, waiting 1.91s (attempt 1/3)
# Rate limit hit for conversation 1246, waiting 1.73s (attempt 1/3)
# Rate limit hit for conversation 1246, waiting 1.48s (attempt 1/3)
#   Completed 20/25 in batch
# Rate limit hit for conversation 1249, waiting 1.16s (attempt 1/3)
#   Completed 25/25 in batch
#   Batch completed in 38.99s
#   Successful: 25, Failed: 0
#   Total processed: 550/2055
# \nProcessing batch 23: conversations 551-575
# Error parsing UX analysis: 3 validation errors for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': 'было бы ...ype': 'feature_request'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# suggestions.1
#   Input should be a valid string [type=string_type, input_value={'text': 'дать нам...ype': 'feature_request'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# suggestions.2
#   Input should be a valid string [type=string_type, input_value={'text': 'сделать ...ype': 'feature_request'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Error parsing UX analysis: 2 validation errors for UX
# feedback.0
#   Input should be a valid string [type=string_type, input_value={'type': 'system_performa...esent for conversation'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'type': 'agent', 'descri...e for initial response'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 1072, waiting 1.96s (attempt 1/3)
#   Completed 5/25 in batch
# Rate limit hit for conversation 139, waiting 1.34s (attempt 1/3)
# Rate limit hit for conversation 139, waiting 2.52s (attempt 2/3)
#   Completed 10/25 in batch
# Error parsing UX analysis: 2 validation errors for UX
# feedback.0
#   Input should be a valid string [type=string_type, input_value={'topic': 'agent system p... 'no feedback provided'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'topic': 'conversation f...ance for new questions'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
#   Completed 15/25 in batch
# Rate limit hit for conversation 331, waiting 1.19s (attempt 1/3)
# Rate limit hit for conversation 1571, waiting 1.80s (attempt 1/3)
#   Completed 20/25 in batch
# Rate limit hit for conversation 1408, waiting 1.64s (attempt 1/3)
# Error parsing UX analysis: 1 validation error for UX
# feedback.0
#   Input should be a valid string [type=string_type, input_value={'text': 'Как отме...: 'information_request'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 1408, waiting 2.55s (attempt 2/3)
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'type': 'improvement', '...n how to update status'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
#   Completed 25/25 in batch
#   Batch completed in 39.64s
#   Successful: 25, Failed: 0
#   Total processed: 575/2055
# \nProcessing batch 24: conversations 576-600
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': 'напиши п...': 'system improvement'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': 'напиши п..., 'type': 'improvement'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 1575, waiting 1.17s (attempt 1/3)
#   Completed 5/25 in batch
#   Completed 10/25 in batch
#   Completed 15/25 in batch
# Rate limit hit for conversation 198, waiting 1.08s (attempt 1/3)
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'idea': 'improve documen...departmental resources'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 198, waiting 2.86s (attempt 2/3)
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': 'внести в...lude the fact in tasks'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
#   Completed 20/25 in batch
# Rate limit hit for conversation 204, waiting 1.27s (attempt 1/3)
# Rate limit hit for conversation 206, waiting 1.44s (attempt 1/3)
#   Completed 25/25 in batch
#   Batch completed in 36.70s
#   Successful: 25, Failed: 0
#   Total processed: 600/2055
# \nProcessing batch 25: conversations 601-625
# Rate limit hit for conversation 46, waiting 1.74s (attempt 1/3)
#   Completed 5/25 in batch
#   Completed 10/25 in batch
# Rate limit hit for conversation 544, waiting 1.91s (attempt 1/3)
# Error parsing UX analysis: 1 validation error for UX
# feedback.0
#   Input should be a valid string [type=string_type, input_value={'type': 'system_performa...eking help or guidance'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 544, waiting 2.77s (attempt 2/3)
# Rate limit hit for conversation 334, waiting 1.13s (attempt 1/3)
#   Completed 15/25 in batch
# Error parsing UX analysis: 2 validation errors for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': 'поле с з...ory': 'feature_request'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# suggestions.1
#   Input should be a valid string [type=string_type, input_value={'text': 'подвеси...ory': 'feature_request'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
#   Completed 20/25 in batch
# Rate limit hit for conversation 1518, waiting 1.11s (attempt 1/3)
# Rate limit hit for conversation 845, waiting 1.99s (attempt 1/3)
# Rate limit hit for conversation 1144, waiting 1.02s (attempt 1/3)
#   Completed 25/25 in batch
#   Batch completed in 35.60s
#   Successful: 25, Failed: 0
#   Total processed: 625/2055
# \nProcessing batch 26: conversations 626-650
# Rate limit hit for conversation 1145, waiting 1.70s (attempt 1/3)
#   Completed 5/25 in batch
# Rate limit hit for conversation 890, waiting 1.33s (attempt 1/3)
# Rate limit hit for conversation 1147, waiting 1.50s (attempt 1/3)
#   Completed 10/25 in batch
# Rate limit hit for conversation 891, waiting 1.97s (attempt 1/3)
#   Completed 15/25 in batch
# Rate limit hit for conversation 767, waiting 1.90s (attempt 1/3)
# Rate limit hit for conversation 894, waiting 1.15s (attempt 1/3)
# Rate limit hit for conversation 894, waiting 2.03s (attempt 2/3)
#   Completed 20/25 in batch
#   Completed 25/25 in batch
#   Batch completed in 37.20s
#   Successful: 25, Failed: 0
#   Total processed: 650/2055
# \nProcessing batch 27: conversations 651-675
# Rate limit hit for conversation 895, waiting 1.12s (attempt 1/3)
# Rate limit hit for conversation 895, waiting 1.20s (attempt 1/3)
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'type': 'improvement', '...respond with job title'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
#   Completed 5/25 in batch
# Rate limit hit for conversation 897, waiting 1.38s (attempt 1/3)
#   Completed 10/25 in batch
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': 'Add more detail...ategory': 'information'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 897, waiting 1.23s (attempt 1/3)
# Rate limit hit for conversation 1038, waiting 1.21s (attempt 1/3)
#   Completed 15/25 in batch
# Rate limit hit for conversation 1668, waiting 1.35s (attempt 1/3)
#   Completed 20/25 in batch
#   Completed 25/25 in batch
#   Batch completed in 37.21s
#   Successful: 25, Failed: 0
#   Total processed: 675/2055
# \nProcessing batch 28: conversations 676-700
# Error parsing UX analysis: 2 validation errors for UX
# feedback.0
#   Input should be a valid string [type=string_type, input_value={'category': 'agent', 'text': 'none'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': 'provide clear g...es from previous years'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 1149, waiting 1.18s (attempt 1/3)
# Rate limit hit for conversation 1149, waiting 2.66s (attempt 2/3)
# Error parsing UX analysis: 2 validation errors for UX
# feedback.0
#   Input should be a valid string [type=string_type, input_value={'topic': 'task assignmen...l tasks to be assigned'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'topic': 'task managemen...ith clear instructions'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit exceeded for conversation 1149 after 3 attempts
#   Completed 5/25 in batch
#   Completed 10/25 in batch
# Rate limit hit for conversation 600, waiting 1.74s (attempt 1/3)
# Rate limit hit for conversation 600, waiting 2.24s (attempt 2/3)
# Error parsing UX analysis: 1 validation error for UX
# feedback.0
#   Input should be a valid string [type=string_type, input_value={'topic': 'agent', 'comme...o agents were involved'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit exceeded for conversation 600 after 3 attempts
#   Completed 15/25 in batch
# Rate limit hit for conversation 778, waiting 1.07s (attempt 1/3)
#   Completed 20/25 in batch
# Rate limit hit for conversation 602, waiting 1.33s (attempt 1/3)
# Rate limit hit for conversation 602, waiting 2.03s (attempt 2/3)
#   Completed 25/25 in batch
#   Batch completed in 34.37s
#   Successful: 25, Failed: 0
#   Total processed: 700/2055
# \nProcessing batch 29: conversations 701-725
# Rate limit hit for conversation 603, waiting 1.89s (attempt 1/3)
#   Completed 5/25 in batch
# Rate limit hit for conversation 1441, waiting 1.33s (attempt 1/3)
# Rate limit hit for conversation 1442, waiting 1.32s (attempt 1/3)
# Rate limit hit for conversation 960, waiting 1.23s (attempt 1/3)
# Rate limit hit for conversation 960, waiting 2.28s (attempt 2/3)
# Error parsing UX analysis: 1 validation error for UX
# feedback.0
#   Input should be a valid string [type=string_type, input_value={'topic': 'system perform... 'request for feedback'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
#   Completed 10/25 in batch
#   Completed 15/25 in batch
# Rate limit hit for conversation 965, waiting 1.73s (attempt 1/3)
# Rate limit hit for conversation 1576, waiting 1.39s (attempt 1/3)
#   Completed 20/25 in batch
# Rate limit hit for conversation 1576, waiting 2.33s (attempt 2/3)
# Rate limit hit for conversation 1687, waiting 1.57s (attempt 1/3)
#   Completed 25/25 in batch
#   Batch completed in 37.44s
#   Successful: 25, Failed: 0
#   Total processed: 725/2055
# \nProcessing batch 30: conversations 726-750
# Error processing conversation 546: Error code: 400 - {'error': {'message': "Failed to generate JSON. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'json_validate_failed', 'failed_generation': '{\n   "sentiment": "neutral",\n   "sentiment_confidence": 1.0,\n   "emotions": [],\n   "feedback": [\n      "bug" in the task suggests system performance issues"\\n   ],\\n   "suggestions": [\\n      "provide more accurate task assignment"\\n   ],\\n   "is_successful": true\\n}}'}}
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'type': 'task_assignment...n Novosibirsk on 05/24'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 1714, waiting 1.75s (attempt 1/3)
# Error parsing UX analysis: 2 validation errors for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'description': 'Add a cl...ory': 'task management'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# suggestions.1
#   Input should be a valid string [type=string_type, input_value={'description': 'Provide ...ry': 'task description'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 1688, waiting 1.89s (attempt 1/3)
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': 'Provide more cl...ategory': 'information'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 1714, waiting 1.84s (attempt 1/3)
#   Completed 5/25 in batch
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': 'Provide more de...type': 'improve_system'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 1716, waiting 1.17s (attempt 1/3)
#   Completed 10/25 in batch
# Rate limit hit for conversation 967, waiting 1.47s (attempt 1/3)
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': 'покажи в..., 'type': 'improvement'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
#   Completed 15/25 in batch
# Rate limit hit for conversation 1252, waiting 1.72s (attempt 1/3)
# Rate limit hit for conversation 52, waiting 1.27s (attempt 1/3)
# Rate limit hit for conversation 1252, waiting 2.93s (attempt 2/3)
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
# ...
#   Completed 25/25 in batch
#   Batch completed in 36.70s
#   Successful: 25, Failed: 0
#   Total processed: 1650/2055
# \nProcessing batch 67: conversations 1651-1675
# Rate limit hit for conversation 821, waiting 1.87s (attempt 1/3)
# Rate limit hit for conversation 821, waiting 1.12s (attempt 1/3)
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': 'More detailed e...mains would be helpful'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
#   Completed 5/25 in batch
#   Completed 10/25 in batch
# Rate limit hit for conversation 252, waiting 1.28s (attempt 1/3)
# Rate limit hit for conversation 1557, waiting 1.91s (attempt 1/3)
# Rate limit hit for conversation 1544, waiting 1.99s (attempt 1/3)
#   Completed 15/25 in batch
# Rate limit hit for conversation 1650, waiting 1.85s (attempt 1/3)
#   Completed 20/25 in batch
# Rate limit hit for conversation 1488, waiting 1.72s (attempt 1/3)
#   Completed 25/25 in batch
#   Batch completed in 35.95s
#   Successful: 25, Failed: 0
#   Total processed: 1675/2055
# \nProcessing batch 68: conversations 1676-1700
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': 'More relevant l...pful', 'category': 'ux'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
#   Completed 5/25 in batch
# Rate limit hit for conversation 115, waiting 1.17s (attempt 1/3)
#   Completed 10/25 in batch
# Rate limit hit for conversation 2000, waiting 1.90s (attempt 1/3)
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': ' improve questi...ess', 'type': 'feature'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': 'Provide more in..., 'type': 'information'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
#   Completed 15/25 in batch
# Rate limit hit for conversation 116, waiting 1.35s (attempt 1/3)
#   Completed 20/25 in batch
# Rate limit hit for conversation 2013, waiting 1.39s (attempt 1/3)
#   Completed 25/25 in batch
#   Batch completed in 39.71s
#   Successful: 25, Failed: 0
#   Total processed: 1700/2055
# \nProcessing batch 69: conversations 1701-1725
# Rate limit hit for conversation 508, waiting 1.86s (attempt 1/3)
#   Completed 5/25 in batch
# Rate limit hit for conversation 2001, waiting 1.39s (attempt 1/3)
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'type': 'system', 'descr...name of the CRM system'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 2001, waiting 2.52s (attempt 2/3)
#   Completed 10/25 in batch
# Rate limit hit for conversation 1381, waiting 1.87s (attempt 1/3)
# Error parsing UX analysis: 1 validation error for UX
# feedback.0
#   Input should be a valid string [type=string_type, input_value={'type': 'performance', '...n': 'no agent response'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 822, waiting 1.76s (attempt 1/3)
#   Completed 15/25 in batch
# Rate limit hit for conversation 825, waiting 1.78s (attempt 1/3)
#   Completed 20/25 in batch
#   Completed 25/25 in batch
#   Batch completed in 35.40s
#   Successful: 25, Failed: 0
#   Total processed: 1725/2055
# \nProcessing batch 70: conversations 1726-1750
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': 'Создай н...ype': 'feature_request'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': 'создава...uest for prompt action'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': 'more detailed i...': 'system improvement'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 159, waiting 1.36s (attempt 1/3)
#   Completed 5/25 in batch
# Error parsing UX analysis: 3 validation errors for UX
# feedback.0
#   Input should be a valid string [type=string_type, input_value={'topic': 'site update', ...back about site update'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'topic': 'site update', ...ers about site updates'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# suggestions.1
#   Input should be a valid string [type=string_type, input_value={'topic': 'product presen...r product presentation'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 163, waiting 1.96s (attempt 1/3)
#   Completed 10/25 in batch
# Rate limit hit for conversation 1832, waiting 1.86s (attempt 1/3)
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'type': 'improvement', '...upport contact methods'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'topic': 'organization',...cipants in the meeting'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': 'Найди св...ategory': 'convenience'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 1832, waiting 1.40s (attempt 1/3)
# Error parsing UX analysis: 2 validation errors for UX
# feedback.0
#   Input should be a valid string [type=string_type, input_value={'type': 'information_req...target': 'agent_system'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'type': 'improvement', '...lities and limitations'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
#   Completed 15/25 in batch
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': 'В каком ...t the office structure'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': 'Протоко... выполнения'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
#   Completed 20/25 in batch
# Rate limit hit for conversation 357, waiting 1.97s (attempt 1/3)
# Error parsing UX analysis: 1 validation error for UX
# feedback.0
#   Input should be a valid string [type=string_type, input_value={'category': 'system_perf...out agent capabilities'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
#   Completed 25/25 in batch
#   Batch completed in 37.88s
#   Successful: 25, Failed: 0
#   Total processed: 1750/2055
# \nProcessing batch 71: conversations 1751-1775
# Rate limit hit for conversation 120, waiting 1.18s (attempt 1/3)
#   Completed 5/25 in batch
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': 'Create tasks on...ype': 'feature_request'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 360, waiting 1.18s (attempt 1/3)
#   Completed 10/25 in batch
# Rate limit hit for conversation 829, waiting 1.99s (attempt 1/3)
#   Completed 15/25 in batch
# Rate limit hit for conversation 831, waiting 1.16s (attempt 1/3)
#   Completed 20/25 in batch
# Rate limit hit for conversation 2026, waiting 1.01s (attempt 1/3)
#   Completed 25/25 in batch
#   Batch completed in 47.31s
#   Successful: 25, Failed: 0
#   Total processed: 1775/2055
# \nProcessing batch 72: conversations 1776-1800
#   Completed 5/25 in batch
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'category': 'system', 't...icket creation process'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
#   Completed 10/25 in batch
# Rate limit hit for conversation 2022, waiting 1.80s (attempt 1/3)
#   Completed 15/25 in batch
#   Completed 20/25 in batch
#   Completed 25/25 in batch
#   Batch completed in 21.97s
#   Successful: 25, Failed: 0
#   Total processed: 1800/2055
# \nProcessing batch 73: conversations 1801-1825
# Error parsing UX analysis: 2 validation errors for UX
# feedback.0
#   Input should be a valid string [type=string_type, input_value={'type': 'system_performa...equest for information'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'type': 'information_pro...e information about 42'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
#   Completed 5/25 in batch
# Rate limit hit for conversation 1906, waiting 1.10s (attempt 1/3)
#   Completed 10/25 in batch
# Rate limit hit for conversation 2036, waiting 1.19s (attempt 1/3)
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': 'Provide more in... 'type': 'product_info'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 2036, waiting 1.21s (attempt 1/3)
# Error parsing UX analysis: 1 validation error for UX
# feedback.0
#   Input should be a valid string [type=string_type, input_value={'category': 'agent', 'text': 'none'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
#   Completed 15/25 in batch
# Rate limit hit for conversation 127, waiting 1.09s (attempt 1/3)
#   Completed 20/25 in batch
#   Completed 25/25 in batch
#   Batch completed in 33.26s
#   Successful: 25, Failed: 0
#   Total processed: 1825/2055
# \nProcessing batch 74: conversations 1826-1850
#   Completed 5/25 in batch
# Rate limit hit for conversation 663, waiting 1.40s (attempt 1/3)
# Rate limit hit for conversation 664, waiting 1.10s (attempt 1/3)
# Rate limit hit for conversation 732, waiting 1.58s (attempt 1/3)
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': 'proанализ..., 'type': 'improvement'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 1521, waiting 1.23s (attempt 1/3)
#   Completed 10/25 in batch
# Error parsing UX analysis: 1 validation error for UX
# feedback.0
#   Input should be a valid string [type=string_type, input_value={'category': 'info_reques...f integration with RTO'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 668, waiting 1.69s (attempt 1/3)
#   Completed 15/25 in batch
# Rate limit hit for conversation 1912, waiting 1.26s (attempt 1/3)
#   Completed 20/25 in batch
# Error parsing UX analysis: 2 validation errors for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'category': 'conversatio...ium clients definition'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# suggestions.1
#   Input should be a valid string [type=string_type, input_value={'category': 'agent', 'de... new tariff regulation'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 1707, waiting 1.32s (attempt 1/3)
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'type': 'feature', 'desc...authorization requests'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
#   Completed 25/25 in batch
#   Batch completed in 36.36s
#   Successful: 25, Failed: 0
#   Total processed: 1850/2055
# \nProcessing batch 75: conversations 1851-1875
#   Completed 5/25 in batch
# Rate limit hit for conversation 564, waiting 1.12s (attempt 1/3)
# Error parsing UX analysis: 1 validation error for UX
# feedback.0
#   Input should be a valid string [type=string_type, input_value={'issue': 'none', 'descri...is seeking information'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 1631, waiting 1.68s (attempt 1/3)
# Error parsing UX analysis: 1 validation error for UX
# feedback.0
#   Input should be a valid string [type=string_type, input_value={'topic': 'system accurac... 'importance': 'medium'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
#   Completed 10/25 in batch
# Rate limit hit for conversation 916, waiting 1.11s (attempt 1/3)
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={' suggestion': 'Provide ...e and prioritize tasks'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Error parsing UX analysis: 1 validation error for UX
# feedback.0
#   Input should be a valid string [type=string_type, input_value={'topic': 'system perform... проверь еще'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 917, waiting 1.89s (attempt 1/3)
#   Completed 15/25 in batch
# Rate limit hit for conversation 1634, waiting 1.77s (attempt 1/3)
#   Completed 20/25 in batch
# Rate limit hit for conversation 1635, waiting 1.26s (attempt 1/3)
#   Completed 25/25 in batch
#   Batch completed in 37.11s
#   Successful: 25, Failed: 0
#   Total processed: 1875/2055
# \nProcessing batch 76: conversations 1876-1900
# Rate limit hit for conversation 261, waiting 1.92s (attempt 1/3)
# Rate limit hit for conversation 258, waiting 1.26s (attempt 1/3)
#   Completed 5/25 in batch
# Rate limit hit for conversation 264, waiting 1.25s (attempt 1/3)
# Rate limit hit for conversation 264, waiting 2.57s (attempt 2/3)
#   Completed 10/25 in batchRate limit hit for conversation 514, waiting 1.41s (attempt 1/3)
#
#   Completed 15/25 in batch
# Rate limit hit for conversation 1637, waiting 1.83s (attempt 1/3)
#   Completed 20/25 in batch
# Rate limit hit for conversation 1355, waiting 1.51s (attempt 1/3)
# Error parsing UX analysis: 1 validation error for UX
# suggestions.0
#   Input should be a valid string [type=string_type, input_value={'text': 'Start implement..., 'type': 'improvement'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type
# Rate limit hit for conversation 1356, waiting 1.59s (attempt 1/3)

# %%
## Analysis Summary and Validation

def validate_analysis_completeness():
	"""Validate that all conversations have complete analysis."""
	print("=== Analysis Validation ===")
	
	# Check analysis completeness
	total_conversations = len(conversations)
	complete_analysis_count = 0
	ux_analysis_count = 0
	intent_analysis_count = 0
	problem_analysis_count = 0
	
	for conv in conversations:
		if conv.analysis:
			analysis_complete = True
			
			# Check UX analysis
			if conv.analysis.ux and hasattr(conv.analysis.ux, 'sentiment'):
				ux_analysis_count += 1
			else:
				analysis_complete = False
			
			# Check Intent analysis  
			if conv.analysis.request and conv.analysis.request.intent:
				intent_analysis_count += 1
			else:
				analysis_complete = False
				
			# Check Problem analysis
			if conv.analysis.problems:
				problem_analysis_count += 1
			else:
				analysis_complete = False
			
			if analysis_complete:
				complete_analysis_count += 1
	
	print(f"Total conversations: {total_conversations}")
	print(f"Complete analysis: {complete_analysis_count} ({complete_analysis_count/total_conversations*100:.1f}%)")
	print(f"UX analysis: {ux_analysis_count} ({ux_analysis_count/total_conversations*100:.1f}%)")
	print(f"Intent analysis: {intent_analysis_count} ({intent_analysis_count/total_conversations*100:.1f}%)")
	print(f"Problem analysis: {problem_analysis_count} ({problem_analysis_count/total_conversations*100:.1f}%)")
	
	return complete_analysis_count, ux_analysis_count, intent_analysis_count, problem_analysis_count

def show_analysis_samples():
	"""Show sample analysis results."""
	print("\n=== Sample Analysis Results ===")
	
	# Find conversations with complete analysis
	complete_conversations = [
		conv for conv in conversations 
		if conv.analysis and conv.analysis.ux and conv.analysis.request and conv.analysis.request.intent
	]
	
	if complete_conversations:
		# Show a few examples
		for i, conv in enumerate(complete_conversations[:3]):
			print(f"\n--- Sample {i+1}: Conversation {conv.dialogue_id} ---")
			print(f"Duration: {conv.duration_minutes} minutes, Messages: {conv.message_count}")
			
			# UX Analysis
			print(f"UX Analysis:")
			print(f"  Sentiment: {conv.analysis.ux.sentiment.value} (confidence: {conv.analysis.ux.sentiment_confidence:.2f})")
			print(f"  Emotions: {[e.value for e in conv.analysis.ux.emotions]}")
			print(f"  Success: {conv.analysis.ux.is_successful}")
			if conv.analysis.ux.feedback:
				print(f"  Feedback: {conv.analysis.ux.feedback[:1]}")  # Show first feedback item
			
			# Intent Analysis
			print(f"Intent Analysis:")
			print(f"  Category: {[c.value for c in conv.analysis.request.category]}")
			print(f"  Intent: {[i.value for i in conv.analysis.request.intent]}")
			
			# Problem Analysis
			if conv.analysis.problems.problems:
				print(f"Problems: {[p.value for p in conv.analysis.problems.problems]}")
			else:
				print("Problems: None detected")
	else:
		print("No conversations with complete analysis found.")

def generate_final_statistics():
	"""Generate comprehensive statistics."""
	print("\n=== Final Pipeline Statistics ===")
	
	# UX Statistics
	ux_sentiments = {}
	ux_emotions = {}
	success_rate = 0
	
	# Intent Statistics  
	intent_categories = {}
	intent_types = {}
	
	# Problem Statistics
	problem_types = {}
	
	analyzed_count = 0
	
	for conv in conversations:
		if conv.analysis:
			analyzed_count += 1
			
			# UX stats
			if conv.analysis.ux:
				sentiment = conv.analysis.ux.sentiment.value
				ux_sentiments[sentiment] = ux_sentiments.get(sentiment, 0) + 1
				
				if conv.analysis.ux.is_successful:
					success_rate += 1
					
				for emotion in conv.analysis.ux.emotions:
					ux_emotions[emotion.value] = ux_emotions.get(emotion.value, 0) + 1
			
			# Intent stats
			if conv.analysis.request:
				for category in conv.analysis.request.category:
					intent_categories[category.value] = intent_categories.get(category.value, 0) + 1
				for intent in conv.analysis.request.intent:
					intent_types[intent.value] = intent_types.get(intent.value, 0) + 1
			
			# Problem stats
			if conv.analysis.problems:
				for problem in conv.analysis.problems.problems:
					problem_types[problem.value] = problem_types.get(problem.value, 0) + 1
	
	print(f"Analyzed conversations: {analyzed_count}/{len(conversations)}")
	print(f"Success rate: {success_rate}/{analyzed_count} ({success_rate/analyzed_count*100:.1f}%)" if analyzed_count > 0 else "Success rate: N/A")
	
	print(f"\nTop UX Sentiments:")
	for sentiment, count in sorted(ux_sentiments.items(), key=lambda x: x[1], reverse=True):
		print(f"  {sentiment}: {count} ({count/analyzed_count*100:.1f}%)")
	
	print(f"\nTop Intent Categories:")
	for category, count in sorted(intent_categories.items(), key=lambda x: x[1], reverse=True)[:5]:
		print(f"  {category}: {count} ({count/analyzed_count*100:.1f}%)")
	
	print(f"\nTop Intent Types:")
	for intent, count in sorted(intent_types.items(), key=lambda x: x[1], reverse=True)[:5]:
		print(f"  {intent}: {count} ({count/analyzed_count*100:.1f}%)")
	
	print(f"\nTop Problem Types:")
	for problem, count in sorted(problem_types.items(), key=lambda x: x[1], reverse=True)[:5]:
		print(f"  {problem}: {count} ({count/analyzed_count*100:.1f}%)")

# Run validation and show results
validate_analysis_completeness()
show_analysis_samples()
generate_final_statistics()

print(f"\n🎉 Conversation Analysis Pipeline Complete!")
print(f"✅ All 3 stages completed successfully")
print(f"📊 Enhanced analysis includes UX, Intent, and Problem detection")
print(f"💾 Results saved to: {CONVERSATIONS_FILE}")
